# %%
import math
import torch
import numpy as np
import gpytorch
import pandas as pd
from matplotlib import pyplot as plt

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
filename = r'data/olhs_run1.xlsx'
data_pd = pd.read_excel(filename, sheet_name='data', header=[0,1], index_col=[0,1])

# %%
data_pd
# Out:
# Yield T                                  Yield A Condition Manufacturability  \
# mg                                            mg        --                --
# 1  2161.24                               1615.10        HO                 v
# 2  1014.1929999999999                     985.46        PS                XX
# 3  1127.465                              1105.65        PS                XX
# 4  1080.744                               980.46        PS                XX
# 5  929.36                                 617.80        HO                 v
# 6  956.909                                950.50        PS                 v
# 7  947.211                                989.70        HO                 v
# 8  1277.3300000000002                    1226.20        HO                 x
# 9  864.724                                933.40        PS                 v
# 10 1130.86                               1180.50        HO                 v
# ...
